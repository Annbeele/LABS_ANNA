# %% [markdown]
# # MY HOLIDAYS PREFERENCE

# %% [markdown]
# ### The purpose of this notebook is to introduce myself and my holidays preference. I will also show a picture and a link to a youtube video so that you can imagine which beautiful place i'm referring to.

# %%
def name():
    #print()
    n=input("Write your name: ")
    
    print("Welcome", n)
    return

# %%
name()
# Out:
# Write your name: Anna
# Welcome Anna

# %% [markdown]
# ![unnamed.jpeg](attachment:unnamed.jpeg)

# %%
def holidays_preference():
    #print()
    q=input("Do you prefer to spend your holidays in the beach or in the mountains?: ")
    q2=input("Would you rather go on a backpack trip or go to a luxury hotel? ")
    q3=input("Where would you like spend your summer holidays? ")
    
    print("Wow, what a beautiful place to go! For sure you're gonna have a great time! ")
    
    return

# %%
holidays_preference()
# Out:
# Do you prefer to spend your holidays in the beach or in the mountains?: In the beach!
# Would you rather go on a backpack trip or go to a luxury hotel? Luxury hotel
# Where would you like spend your summer holidays? At the Maldives
# Wow, what a beautiful place to go! For sure you're gonna have a great time!

# %% [markdown]
# ![9923_ho_00_p_1024x768.jpg](attachment:9923_ho_00_p_1024x768.jpg)

# %% [markdown]
# <font color=blue>
# <i>
# <ul>
# <li>Scuba diving</li>
#
# <li>Sunbathing while drinking coconut water </li>
# <li>Eating seafood</li>
# </ul>
# </i>
# </font>

# %% [markdown]
# [Click here to travel to Maldives right now!](https://www.youtube.com/watch?v=FMEXKouHaQ0)
